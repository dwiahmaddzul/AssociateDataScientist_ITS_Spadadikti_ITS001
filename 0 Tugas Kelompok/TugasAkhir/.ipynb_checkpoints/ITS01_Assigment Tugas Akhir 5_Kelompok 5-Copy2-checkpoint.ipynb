# %%
# Importing the libraries
import numpy as np #allow to make arrays
import matplotlib.pyplot as plt #visualize results on charts 
import pandas as pd #import dataset and manage easily

# %%
# Importing the training set - only importing training set, test set later  on 
#rnn has no idea of the test set's data, then after training is done, test set will eb important
dataset_train = pd.read_csv('Import-ekspor-banten.csv',decimal=',')

#need to make into numpy arrays because only nump arrays can be input values in keras
training_set = dataset_train.iloc[:, 1:2].values 

#getting everything from the columns (.values makes the numpy array)

# %%
# Feature Scaling
#2 ways: take obs- min ofstock prices/max of stock prices- min of stock prices
#using normalization instead of standardisation- look at meaning
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set) #fit (gets min and max on data to apply formula) tranform(compute scale stock prices to each formula)

# %%
# Creating a data structure with 60 timesteps and 1 output
#60 times steps- at each time t and look at 60 previous time steps, then make new prediction 
# 1 time step leads to overfitting, 20 is still too low
#60 previous financial days- in 3 months 
X_train = []
y_train = []
for i in range(30, len(training_set)): # upper bound is number of values 
  X_train.append(training_set_scaled[i-30:i, 0]) #takes 60 previous stock prices from 60 past stock prices
  y_train.append(training_set_scaled[i, 0]) #contains stock price learned to predict 
X_train, y_train = np.array(X_train), np.array(y_train) # make into numpy arrays 
#Need to add dimension to because not only prescition with one stock price but other indicators (like other columns in dataset  or other stocks that may affect this one )

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1)) #adds dimension in numpy array

# %%
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
regressor = Sequential() #reps sequence of layers, predicting continous values (so it is a regression)

# %%
# Adding the first LSTM layer and some Dropout regularisation
#dropout to prevent overfitting
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))#regressor- object of sequential class, can add layers to networ.
#use lstm class and create object of lstm class- 3 args
#num of units, return sequences- set to true because is stacked lstms, and shape
#units- neurons in first layer. 50 in layers for high dimensionality, can capture upward and downward
regressor.add(Dropout(0.2))
# takes arg of dropout late- num of neurons want to drop. dropping 20% of neurons to be ignored during trianingn for each iteratin. 10 neurons will be dropped out

# %%
# Adding a second LSTM layer and some Dropout regularisation
# total of 4 layers, simply need to copy, only change is input shape so dont need to specify that, automatically recognised through input shape

regressor.add(LSTM(units = 50, return_sequences = True)) 

regressor.add(Dropout(0.2))

# %%
# Adding a third LSTM layer and some Dropout regularisation
# same as second layer 
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# %%
# Adding a fourth LSTM layer and some Dropout regularisation
# almost same, but return sequence is false because it is the last lstm layer (so it is removed becasue default is false)
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# %%
# Adding the output layer
#add fully connected layer through dense class- dimesion/units/neurons is 1
regressor.add(Dense(units = 1))

# %%
# Compiling the RNN
#regressior because predicting continuous value, 
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Fitting the RNN to the Training set
#have not made connection to training set, training will take place
regressor.fit(X_train, y_train, epochs = 200, batch_size = 32) # CHANGE BACK TO 100 IF NOT WORK
#100 gives good convergence
# trained on certain batch sizes,
# Out:
# Epoch 1/200
# 5/5 [==============================] - 10s 45ms/step - loss: 0.2571
# Epoch 2/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0709
# Epoch 3/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0351
# Epoch 4/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0504
# Epoch 5/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0250
# Epoch 6/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0279
# Epoch 7/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0286
# Epoch 8/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0226
# Epoch 9/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0228
# Epoch 10/200
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0220
# Epoch 11/200
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0240
# Epoch 12/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0244
# Epoch 13/200
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0230
# Epoch 14/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0221
# Epoch 15/200
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0204
# Epoch 16/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0210
# Epoch 17/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0226
# Epoch 18/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0238
# Epoch 19/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0236
# Epoch 20/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0250
# Epoch 21/200
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0244
# Epoch 22/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0263
# Epoch 23/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0213
# Epoch 24/200
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0249
# Epoch 25/200
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0268
# Epoch 26/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0228: 0s - loss: 0.022
# Epoch 27/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0208
# Epoch 28/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0230
# Epoch 29/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0230
# Epoch 30/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0233
# Epoch 31/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0216
# Epoch 32/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0221
# Epoch 33/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0213
# Epoch 34/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0238
# Epoch 35/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0227
# Epoch 36/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0216
# Epoch 37/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0231
# Epoch 38/200
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0243: 0s - loss: 0.02
# Epoch 39/200
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0239
# Epoch 40/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0246
# Epoch 41/200
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0248
# Epoch 42/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0334
# Epoch 43/200
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0181
# Epoch 44/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0229
# Epoch 45/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0227
# Epoch 46/200
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0218
# Epoch 47/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0232: 0s - loss: 0.
# Epoch 48/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0179
# Epoch 49/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0205
# Epoch 50/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0245
# Epoch 51/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0232
# Epoch 52/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0224
# Epoch 53/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0208
# Epoch 54/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0236
# Epoch 55/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0204
# Epoch 56/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0182
# Epoch 57/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0204
# Epoch 58/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0217
# Epoch 59/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0280
# Epoch 60/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0202
# Epoch 61/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0286
# Epoch 62/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0217
# Epoch 63/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0216
# Epoch 64/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0204
# Epoch 65/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0224
# Epoch 66/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0212
# Epoch 67/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0198
# Epoch 68/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0208
# Epoch 69/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0300
# Epoch 70/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0192
# Epoch 71/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0213
# Epoch 72/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0225
# Epoch 73/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0216
# Epoch 74/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0199
# Epoch 75/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0204
# Epoch 76/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0194
# Epoch 77/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0211
# Epoch 78/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0191
# Epoch 79/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0204
# Epoch 80/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0182
# Epoch 81/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0202
# Epoch 82/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0227
# Epoch 83/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0199
# Epoch 84/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0216
# Epoch 85/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0209
# Epoch 86/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0265
# Epoch 87/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0204
# Epoch 88/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0191
# Epoch 89/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0228
# Epoch 90/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0213
# Epoch 91/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0238
# Epoch 92/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0192
# Epoch 93/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0186
# Epoch 94/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0215
# Epoch 95/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0160
# Epoch 96/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0205
# Epoch 97/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0207
# Epoch 98/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0192
# Epoch 99/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0209
# Epoch 100/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0190
# Epoch 101/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0211
# Epoch 102/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0186
# Epoch 103/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0248
# Epoch 104/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0201
# Epoch 105/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0248
# Epoch 106/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0195
# Epoch 107/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0273
# Epoch 108/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0177
# Epoch 109/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0193
# Epoch 110/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0228
# Epoch 111/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0220
# Epoch 112/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0193
# Epoch 113/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0200
# Epoch 114/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0204
# Epoch 115/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0193
# Epoch 116/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0163
# Epoch 117/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0190
# Epoch 118/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0193
# Epoch 119/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0195
# Epoch 120/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0166
# Epoch 121/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0203
# Epoch 122/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0182
# Epoch 123/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0164
# Epoch 124/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0170
# Epoch 125/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0209
# Epoch 126/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0197
# Epoch 127/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0187
# Epoch 128/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0191
# Epoch 129/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0188
# Epoch 130/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0174
# Epoch 131/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0190
# Epoch 132/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0200
# Epoch 133/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0197
# Epoch 134/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0195
# Epoch 135/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0166
# Epoch 136/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0166
# Epoch 137/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0147
# Epoch 138/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0175
# Epoch 139/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0168
# Epoch 140/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0167
# Epoch 141/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0177
# Epoch 142/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0161
# Epoch 143/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0193
# Epoch 144/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0160
# Epoch 145/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0184
# Epoch 146/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0176
# Epoch 147/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0163
# Epoch 148/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0179
# Epoch 149/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0165
# Epoch 150/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0179
# Epoch 151/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0175
# Epoch 152/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0172
# Epoch 153/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0175
# Epoch 154/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0160
# Epoch 155/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0168
# Epoch 156/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0222
# Epoch 157/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0183
# Epoch 158/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0174
# Epoch 159/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0175
# Epoch 160/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0164
# Epoch 161/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0155
# Epoch 162/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0188
# Epoch 163/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0165
# Epoch 164/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0190
# Epoch 165/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0190
# Epoch 166/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0157
# Epoch 167/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0172
# Epoch 168/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0180
# Epoch 169/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0157
# Epoch 170/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0159
# Epoch 171/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0162
# Epoch 172/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0136
# Epoch 173/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0161
# Epoch 174/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0159
# Epoch 175/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0155
# Epoch 176/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0170
# Epoch 177/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0163
# Epoch 178/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0161
# Epoch 179/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0153
# Epoch 180/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0154
# Epoch 181/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0157
# Epoch 182/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0169
# Epoch 183/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0196
# Epoch 184/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0157
# Epoch 185/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0159
# Epoch 186/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0149
# Epoch 187/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0161
# Epoch 188/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0160
# Epoch 189/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0171
# Epoch 190/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0202
# Epoch 191/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0155
# Epoch 192/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0181
# Epoch 193/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0161
# Epoch 194/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0161
# Epoch 195/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0158
# Epoch 196/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0142
# Epoch 197/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0153
# Epoch 198/200
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0177
# Epoch 199/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0162
# Epoch 200/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0158

# %%
# Getting the real stock price of 2018
dataset_test = pd.read_csv('Test.csv',decimal=',')
real_stock_price = dataset_test.iloc[:, 1:2].values

# %%
# Getting the predicted stock price of 2018
dataset_total = pd.concat((dataset_train['Neraca'], dataset_test['Neraca']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 30:].values #getting input of each previous financial days
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(30, len(dataset_test)):
    X_test.append(inputs[i-30:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
# Visualising the results
plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
#Calculate/Get the value of RMSE
rmse=np.sqrt(np.mean(((predictions- y_test)**2)))
rmse
# Out:
# 130.87478963452367

# %%
#Plot/Create the data for the graph
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
#Visualize the data
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Neraca'])
plt.plot(valid[['Neraca', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# <ipython-input-27-1cd39b7a1410>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
valid
# Out:
#      Neraca  Predictions
# 128  -37.45  -114.344902
# 129 -134.72  -116.495995
# 130 -137.49  -121.660660
# 131 -102.40  -127.906723
# 132  -91.99  -131.717102
# 133  -58.27  -132.931931
# 134   64.77  -130.113541
# 135 -148.39  -116.316696
# 136   96.17  -112.453293
# 137    0.65   -96.951324
# 138  106.08   -83.012383
# 139  140.02   -63.340744
# 140  -62.28   -39.598534
# 141   77.84   -30.156776
# 142   64.75   -19.290308
# 143   27.74    -9.721557
# 144   -7.06    -4.486999
# 145 -180.43    -4.632968
# 146  -26.01   -20.457651
# 147   94.12   -32.543091
# 148  259.70   -33.232624
# 149  179.71   -15.416374
# 150  219.05     5.395269
# 151  158.28    29.315823
# 152   78.32    48.289440
# 153  174.53    56.715279
# 154   88.74    65.435745
# 155   37.96    66.687897
# 156  -65.68    59.630379
# 157  -69.21    40.698738
# 158 -235.29    16.292315
# 159  -81.49   -21.371208

# %%
#Get the quote
datanew = pd.read_csv('Test.csv',decimal=',')
#Create a new dataframe
new_df = datanew.filter(['Neraca'])
#Get teh last 60 day closing price 
last_60_days = new_df[-30:].values
#Scale the data to be values between 0 and 1
last_60_days_scaled = scaler.transform(last_60_days)
#Create an empty list
X_test = []
#Append teh past 60 days
X_test.append(last_60_days_scaled)
#Convert the X_test data set to a numpy array
X_test = np.array(X_test)
#Reshape the data
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
#Get the predicted scaled price
pred_price = model.predict(X_test)
#undo the scaling 
pred_price = scaler.inverse_transform(pred_price)
print(pred_price)
# Out:
# [[-177.64276]]

# %%
#Get the quote
data2 = pd.read_csv('Test.csv')
print(data2['Neraca'])
# Out:
# 0       46,26
# 1      -51,98
# 2       24,06
# 3      -36,15
# 4      -15,47
# 5       23,26
# 6       73,31
# 7     -148,26
# 8     -239,21
# 9     -114,43
# 10      48,01
# 11     184,26
# 12      96,72
# 13     126,51
# 14      88,58
# 15      72,12
# 16      60,13
# 17     -132,9
# 18      -19,9
# 19     -87,84
# 20      90,42
# 21    -127,89
# 22      59,23
# 23      64,71
# 24     112,01
# 25     -50,67
# 26     100,78
# 27      63,97
# 28     143,92
# 29      33,61
# 30      72,52
# 31     129,01
# 32      58,91
# 33     211,91
# 34     -26,65
# 35    -159,71
# 36      31,27
# 37      37,05
# 38     -76,54
# 39      -10,6
# 40     -49,98
# 41    -109,32
# 42     123,92
# 43    -132,41
# 44      -34,8
# 45     -57,91
# 46      25,92
# 47    -138,32
# 48     201,32
# 49       -347
# 50      42,67
# 51    -137,25
# 52    -300,86
# 53    -108,56
# 54    -124,51
# 55    -164,74
# 56    -211,73
# 57    -392,44
# 58    -423,41
# Name: Neraca, dtype: object
